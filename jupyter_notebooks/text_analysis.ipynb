# %% [markdown]
# We try to find the most influential words in the descriptions taskers provide in relation to the median price they offer. For this purpose, we perform ridge regression (as text classification problems tend to be quite high dimensional, and high dimensional problems are likely to be linearly separable)
#
# https://stats.stackexchange.com/questions/17711/why-does-ridge-regression-classifier-work-quite-well-for-text-classification

# %% [markdown]
# First let's look at los angeles:

# %%
# %run -i 'rubbish/classify_medianprice.py' 'los_angeles'
# Out:
# 2728
# 0.17661223124101288
# 0.5907663762101494
# Most positive features:
# ['code', 'hours', 'truck', 'van', 'first', 'rate', 'does', 'grew', 'tasker', 'see']
# Least positive features:
# ['rooms', 'trained', 'emily', 'request', 'willing', 'assistant', 'where', 'but', 'boxes', 'who']

# %% [markdown]
# New york:

# %%
# %run -i 'rubbish/classify_medianprice.py' 'san_francisco'
# Out:
# 541
# 0.10036284889492986
# 0.6638290950738687
# Most positive features:
# ['truck', 'its', 'able', 'van', 'move', 'only', 'home', 'an', 'services', 'all']
# Least positive features:
# ['around', 'organized', 'new', 'care', 'one', 'it', 'cleaning', 'deliveries', 'where', 'great']

# %%
# %run -i 'rubbish/classify_medianprice.py' 'ny'
# Out:
# 1324
# 0.1452686069492155
# 0.6809827265427748
# Most positive features:
# ['hours', 'rate', 'van', 'see', 'tasks', 'thousands', 'per', 'are', 'first', 'owner']
# Least positive features:
# ['their', 'basic', 'charge', 'who', 'something', 'an', 'need', 'at', 'but', 'efficient']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# ...
